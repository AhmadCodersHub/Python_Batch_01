# %% [markdown]
# ##### Python Comments

# %%
# this is a string example
text = 'this is a car'

# %%
# this is a comment 
text = 'this is a car' #  this is a comment

# %% [markdown]
# ##### list

# %%
# mutable
# sequence type data

# %%
# item accessing methods 
# 1. positive indexing. must start with 0
# 2. negative indexing. must start with -1

# %% [markdown]
# ![p0b2zqc1.png](attachment:1b879912-8615-4e1a-b921-068aac93ffb3.png)

# %%
# positive indexing
number_list = [1,2,3,4,5,6]
print(number_list[5])
# Out:
# 6

# %%
print(number_list[4])
# Out:
# 5

# %%
std_list = ['ali','ahmad','hamza']
print(std_list)
# Out:
# ['ali', 'ahmad', 'hamza']

# %%
print(std_list[0])
print(std_list[2])
# Out:
# ali
# hamza

# %%
std_1 = std_list[0]
print(std_1)
# Out:
# ali

# %%
word = 'car'
fruit = 'apple'
print(word)
print(fruit)
# Out:
# car
# apple

# %%
type(word)
# Out:
# str

# %%
type(fruit)
# Out:
# str
